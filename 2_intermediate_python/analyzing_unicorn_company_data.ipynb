# %% [markdown]
# ### Analyzing unicorn company data
#
# In this workspace, we'll be exploring the relationship between total funding a company receives and its valuation.

# %%
SELECT * 
FROM companies INNER JOIN funding USING(company_id)
# Out:
#       company_id  ...                                   select_investors
# 0            189  ...                                       EQT Partners
# 1            848  ...  Dragonfly Captial, Qiming Venture Partners, DS...
# 2            556  ...              Blackstone, Bessemer Venture Partners
# 3            999  ...                 Goldman Sachs Asset Management, 3L
# 4            396  ...  Insight Partners, Softbank Group, Connect Vent...
# ...          ...  ...                                                ...
# 1069        1002  ...  DST Global, Sequoia Capital China, Gaorong Cap...
# 1070         215  ...                                    Sequoia Capital
# 1071         866  ...  Advent International, PSG, Providence Equity P...
# 1072         651  ...  NetEase Capital, Northern Light Venture Capita...
# 1073         890  ...                                       Bain Capital
#
# [1074 rows x 8 columns]

# %%
import plotly.express as px
px.scatter(df, x="funding", y="valuation", log_x=True, log_y=True, hover_name="company")

# %% [markdown]
# Result: Apparentely there is a positive correlation between the companies funding and valuation.
