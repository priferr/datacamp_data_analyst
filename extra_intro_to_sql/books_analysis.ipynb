# %% [markdown]
# # Introduction to SQL
#
# Here you can access the `books` table used in the course.
#
# ---
# _Note: When using sample integrations such as those that contain course data, you have read-only access. You can run queries, but cannot make any changes such as adding, deleting, or modifying the data (e.g., creating tables, views, etc.)._

# %%
-- Add your own queries here
SELECT * 
FROM books
# Out:
#         id  ...        genre
# 0      1.0  ...  Non Fiction
# 1      2.0  ...      Fiction
# 2      3.0  ...  Non Fiction
# 3      4.0  ...      Fiction
# 4      5.0  ...  Non Fiction
# ..     ...  ...          ...
# 347  346.0  ...  Non Fiction
# 348  347.0  ...      Fiction
# 349  348.0  ...  Non Fiction
# 350  349.0  ...      Fiction
# 351  350.0  ...      Fiction
#
# [352 rows x 5 columns]

# %% [markdown]
# ## Explore Datasets
# Use the `books` table to explore the data and practice your skills!
# - Select only the `title` column.
# - Alias the `title` column as `book_title`.
# - Select the distinct author names from the `author` column.
# - Select all records from the table and limit your results to 10.

# %%
SELECT title AS book_title
FROM books;
# Out:
#                                             book_title
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 347  Wild: From Lost to Found on the Pacific Crest ...
# 348  Winter of the World: Book Two of the Century T...
# 349  Women Food and God: An Unexpected Path to Almo...
# 350                                             Wonder
# 351       Wrecking Ball (Diary of a Wimpy Kid Book 14)
#
# [352 rows x 1 columns]

# %%
SELECT DISTINCT author
FROM books;
# Out:
#                 author
# 0       John Heilemann
# 1      Sheryl Sandberg
# 2         Brené Brown
# 3                   DK
# 4       Rebecca Skloot
# ..                 ...
# 243        Craig Smith
# 244    Laurel Randolph
# 245        Sarah Palin
# 246  Ann Whitford Paul
# 247      Joanna Gaines
#
# [248 rows x 1 columns]

# %%
SELECT *
FROM books
LIMIT 10;
# Out:
#    id                                              title  ...  year        genre
# 0   1                      10-Day Green Smoothie Cleanse  ...  2016  Non Fiction
# 1   2                                  11/22/63: A Novel  ...  2011      Fiction
# 2   3            12 Rules for Life: An Antidote to Chaos  ...  2018  Non Fiction
# 3   4                             1984 (Signet Classics)  ...  2017      Fiction
# 4   5  5,000 Awesome Facts (About Everything!) (Natio...  ...  2019  Non Fiction
# 5   6      A Dance with Dragons (A Song of Ice and Fire)  ...  2011      Fiction
# 6   7  A Game of Thrones / A Clash of Kings / A Storm...  ...  2014      Fiction
# 7   8                     A Gentleman in Moscow: A Novel  ...  2017      Fiction
# 8   9      A Higher Loyalty: Truth, Lies, and Leadership  ...  2018  Non Fiction
# 9  10                          A Man Called Ove: A Novel  ...  2016      Fiction
#
# [10 rows x 5 columns]
